# %%
import  matplotlib.pyplot as plt
f = open('day-3.txt')
instr1 = f.readline()
instr2 = f.readline()

# %%
data1 = instr1.split(',')
data2 = instr2.split(',')
data = ['U7','R6','D4','L4']

# %%
def getPath(data):

    rhist = [0,]
    chist = [0,]
    totdist = [0,]

    r = 0
    c = 0

    for item in data:
        #print(item)
        way = item[0]
        dist = int(item[1:])

        if way=='R':
            c += dist
        elif way=='L':
            c -= dist
        elif way=='U':
            r += dist
        elif way=='D':
            r -= dist
        else:
            raise('ERROR')
        rhist.append(r)
        chist.append(c)
        totdist.append(totdist[-1] + dist)
    return rhist,chist, totdist
    #print(way,dist)

# %%
r1,c1,dist1 = getPath(data1)
r2,c2,dist2 = getPath(data2)

# %%
# %matplotlib notebook
plt.figure(figsize=(8,6))
plt.plot(r1,c1)
plt.plot(r2,c2)


plt.figure(figsize=(8,6))
plt.plot(r1,c1)
plt.plot(r2,c2)

plt.xlim(-400,400)
plt.ylim(-400,400)

#print(829+307)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# <img src="data:image/png;base64,..." width="799.9999826604674">
# (-400, 400)

# %%
# Out:
# [0,
#  1009,
#  1272,
#  1789,
#  2238,
#  3043,
#  3121,
#  3919,
#  4802,
#  5579,
#  6141,
#  6793,
#  7141,
#  8140,
#  8907,
#  9866,
#  10359,
#  10418,
#  11412,
#  11637,
#  11863,
#  12497,
#  12697,
#  13650,
#  13993,
#  14381,
#  14539,
#  15482,
#  16026,
#  16835,
#  17620,
#  18238,
#  18737,
#  19213,
#  19813,
#  20265,
#  20958,
#  21654,
#  22418,
#  23345,
#  23691,
#  24554,
#  25012,
#  25801,
#  26069,
#  26655,
#  27539,
#  28197,
#  28568,
#  29478,
#  29656,
#  30180,
#  30349,
#  31322,
#  31648,
#  32131,
#  32364,
#  32390,
#  33197,
#  33443,
#  34154,
#  34795,
#  34870,
#  35626,
#  35991,
#  36194,
#  36571,
#  37195,
#  37625,
#  38047,
#  38414,
#  38961,
#  39255,
#  40171,
#  40928,
#  41437,
#  41769,
#  41875,
#  42276,
#  42457,
#  42462,
#  42905,
#  43102,
#  43508,
#  44337,
#  45215,
#  45250,
#  46208,
#  46239,
#  46267,
#  46629,
#  46817,
#  47399,
#  47757,
#  48507,
#  49446,
#  49937,
#  50866,
#  51379,
#  51920,
#  52338,
# ...

# %%
plt.figure(figsize=(8,6))

numberOfelem1 = 14
numberOfelem2 = 11

plt.plot(r1[:numberOfelem1],c1[:numberOfelem1])
plt.plot(r2[:numberOfelem2],c2[:numberOfelem2])

# -1159,-376


print(dist1[numberOfelem1-1] + dist2[numberOfelem2-1] - (376-237) - (1346-1159))
#plt.xlim(-00,400)
#plt.ylim(-400,400)
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# 12934
